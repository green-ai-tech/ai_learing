# %% [markdown]
# ```mermaid
# flowchart TD
#
#     A[1. 业务逻辑说明]
#     A_NOTE["NOTE:
#     • 模块解决什么问题
#     • 用户是谁
#     • 输入输出定义
#     • 成功标准"]
#
#     B[2. 业务流程图]
#     B_NOTE["NOTE:
#     • 用户操作流程
#     • 后端处理流程
#     • AI参与位置
#     • 数据保存位置"]
#
#     C[3. Agent模式选择]
#
#     C1[3.1 选择什么模式]
#     C2[3.2 为什么选择]
#     C3[3.3 与其他模式比较]
#     C4[3.4 核心设计原则]
#
#     C4_NOTE["NOTE:
#     • 组件解耦
#     • 流程透明
#     • 状态可追踪
#     • 输出结构化
#     • 可测试
#     • 可替换
#     • 可扩展"]
#
#     D[4. Agent结构设计]
#
#     D1[4.1 整体结构图]
#     D2[4.2 Agent / Skill / Tool组件]
#     D3[4.3 AgentState状态设计]
#     D4[4.4 自动化流程设计]
#     D5[4.5 输入输出JSON Schema]
#
#     D_NOTE["NOTE:
#     核心目标:
#     • 明确状态流转
#     • 明确模块职责
#     • 明确组件边界"]
#
#     E[5. Agent最小可运行测试]
#
#     E1[5.1 状态定义]
#     E2[5.2 系统提示词]
#     E3[5.3 Agent实现]
#     E4[5.4 流程编排]
#     E5[5.5 单元测试]
#
#     E_NOTE["NOTE:
#     先做最小闭环:
#     输入 → Agent → 输出
#     不急着接页面"]
#
#     F[6. 业务模块实现]
#
#     F1[Service层]
#     F2[数据库模型]
#     F3[页面模板]
#     F4[历史记录]
#     F5[日志记录]
#     F6[错误处理]
#
#     F_NOTE["NOTE:
#     AI逻辑工程化
#     接入业务系统"]
#
#     G[7. 控制器实现]
#
#     G1[Router / API]
#     G2[表单提交]
#     G3[页面渲染]
#     G4[JSON接口]
#     G5[前后端联调]
#
#     G_NOTE["NOTE:
#     完成前后端交互
#     完成接口层封装"]
#
#     H[8. 验收与迭代]
#
#     H1[正常输入测试]
#     H2[边界输入测试]
#     H3[历史记录测试]
#     H4[日志 / Debug测试]
#     H5[输出质量测试]
#
#     H_NOTE["NOTE:
#     检查:
#     • 稳定性
#     • 幻觉问题
#     • 可解释性
#     • 用户体验"]
#
#     A --> B
#     B --> C
#     C --> D
#     D --> E
#     E --> F
#     F --> G
#     G --> H
#
#     C --> C1
#     C --> C2
#     C --> C3
#     C --> C4
#
#     D --> D1
#     D --> D2
#     D --> D3
#     D --> D4
#     D --> D5
#
#     E --> E1
#     E --> E2
#     E --> E3
#     E --> E4
#     E --> E5
#
#     F --> F1
#     F --> F2
#     F --> F3
#     F --> F4
#     F --> F5
#     F --> F6
#
#     G --> G1
#     G --> G2
#     G --> G3
#     G --> G4
#     G --> G5
#
#     H --> H1
#     H --> H2
#     H --> H3
#     H --> H4
#     H --> H5
#
#     A --- A_NOTE
#     B --- B_NOTE
#     C4 --- C4_NOTE
#     D --- D_NOTE
#     E --- E_NOTE
#     F --- F_NOTE
#     G --- G_NOTE
#     H --- H_NOTE
# ```
