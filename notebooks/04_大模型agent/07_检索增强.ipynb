# %%
# RAG (Retrievla Augment Generation)

# %% [markdown]
# # 7.1 知识库的建立

# %% [markdown]
# - 向量数据库（检索方便：特征检索，Embedding词嵌入）

# %%
### 1）向量数据库

# %% [markdown]
# - 向量数据库：chromadb
#     - 安装：pip install chromadb

# %%
# !pip install chromadb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 2.8 MB/s  0:00:07m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 1.5 MB/s  0:00:07 eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 1.6 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 1.7 MB/s  0:00:10m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.3 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32/32 [chromadb]/32 [chromadb]etry-sdk]protos]
# ...

# %%
- 数据库访问的API:
    - 安装指令： pip install langchain_chroma

# %%
# !pip install langchain_chroma

# %%
### 2)文档的加载与分割

# %% [markdown]
# - txt文件（包含MD，文件结构）：
# - pdf文件：（主流）
# - html文件：
# - csv文件：

# %%
- langchain 的社区提供大量工具
    - pip instsall langchain_community

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 1.7 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 1.5 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.5 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [langchain_community]ngchain_community]
# ...

# %%
- pdf 的底层依赖包：
    - pip install pypdf
# Out:
#   Cell In[4], line 1
#     - pdf 的底层依赖包：
#                 ^
# SyntaxError: invalid character '：' (U+FF1A)

# %%
# !pip install pypdf

# %%
#1. 加载器
from langchain_community.document_loaders import TextLoader,PyPDFLoader,WebBaseLoader,CSVLoader
#2. 文档切割器
from langchain_text_splitters import RecursiveCharacterTextSplitter

file_path = "/Users/logicye/Code/ai_learning/assets/pdf/01Transformer文本分类.pdf"
loader = PyPDFLoader(file_path)
doc =loader.load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
type(doc)
# Out:
# list

# %%
len(doc)
# Out:
# 19

# %% [markdown]
# # 7.2 检索
