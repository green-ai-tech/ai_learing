# %% [markdown]
# # 1. BaseModel

# %% [markdown]
# - 维护字典dict与json数据的包装器：
#     - 字段： Field（descriptrion="",title="",default=""）

# %%
from pydantic import BaseModel,Field

class Movie(BaseModel):
    title:str = Field(...,description="电影片名")
