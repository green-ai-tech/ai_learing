# %% [markdown]
# # 1.语言分类

# %% [markdown]
# ## 1.1 下载模型（可选：相关的数据集也可以下载）

# %%
import torchaudio
#
da = torchaudio.datasets.SPEECHCOMMANDS(root="E:/Datasets", download=True)
# Out:
# 100%|██████████| 2.26G/2.26G [09:12<00:00, 4.39MB/s]

# %%
from transformers import pipeline
pipeline("audio-classification", model="MIT/ast-finetuned-speech-commands-v2",device="cuda")

# %% [markdown]
# - 下载模型
#     - 本地目录C:

# %% [markdown]
# ## 数据集下载:
#     - 使用transformers提供的工具模块 datasets
#     - 使用pyTorch

# %%
from transformers import pipeline
import torch
pipe = pipeline(
    task="audio-classification", 
    model="E:/models/ast-finetuned-speech-commands-v2", 
    # dtype=torch.bfloat16, 
    # device="cuda"
)
pipe("0a196374_nohash_0.wav")
# Out:
# Device set to use cuda:0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 9
#       2 import torch
#       3 pipe = pipeline(
#       4     task="audio-classification",
#       5     model="E:/models/ast-finetuned-speech-commands-v2",
#       6     # dtype=torch.bfloat16,
#       7     # device="cuda"
#       8 )
# ----> 9 pipe("0a2b400e_nohash_3.wav")
#
# File d:\Programs\Python\Lib\site-packages\transformers\pipelines\audio_classification.py:145, in AudioClassificationPipeline.__call__(self, inputs, **kwargs)
#     111 def __call__(self, inputs: Union[np.ndarray, bytes, str, dict], **kwargs: Any) -> list[dict[str, Any]]:
#     112     """
#     113     Classify the sequence(s) given as inputs. See the [`AutomaticSpeechRecognitionPipeline`] documentation for more
#     114     information.
# ...

# %% [markdown]
# ## 通过Pipeline使用，
