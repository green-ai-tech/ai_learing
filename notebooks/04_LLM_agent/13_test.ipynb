# %% [markdown]
# #===进阶
# 设计一个“智能学术论文助手”系统，满足以下需求：
#
# 用户给出论文主题，系统需并行收集来自三个数据源（arXiv、Google Scholar、Wikipedia）的摘要。
#
# 然后顺序执行：提纲生成 → 正文撰写 → 参考文献整理 → 最终审核。
#
# 审核不通过时需退回到正文撰写阶段（最多3次）。
#
# 需支持未来新增其他数据源，且不影响原有流程。

# %% [markdown]
# 我答：
# - 收集数据源是并行的，考虑使用 '广播/订阅' 范式
# - 论文的产出 是顺序的，收集数据 → 提纲生成 → 正文撰写 → 参考文献整理 → 最终审核，考虑使用 '交接模式'
# ![image.png](attachment:image.png)
