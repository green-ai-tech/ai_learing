# %% [markdown]
# # 分词

# %% [markdown]
# ## 1.1 英文分词

# %% [markdown]
# ## (1) 自然语言分词 -字符串处理（原生+正则表达式）

# %%
text = "I love NLP"
word = text.split()         #sep 指定分割的字符

# %%
# %pyhton -m spacy download en_core_web_sm

# %% [markdown]
# ## 1.2 中文分词

# %% [markdown]
# ## 1.3 分词算法

# %% [markdown]
# - tokenizer 框架（深度学习的分词框架：理解分词法）

# %%
from tokenizers import Tokenizer,models,trainers,pre_tokenizers,decoders

# 1. 构建一个指定模型的分词器
tokenizer = Tokenizer(models.BPE())     #指定的是 BPE模型

# 指定分词器的预分词与解码器
tokenizer =
