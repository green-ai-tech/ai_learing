# %% [markdown]
# # 01_word

# %% [markdown]
# ## 1. 环境安装

# %%
# %pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 6.2 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [python-docx] [python-docx]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 编程

# %% [markdown]
# ```text
# 编程模式：
#     1. 创建文档
#     2. 添加内容
#         - 标题 - 正文 - 标注 - 图片 - 表格 - 分页 - 节
#     3. 保存文档
# ```

# %%
from docx import Document
from docx.shared import Cm, Inches
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
from docx.oxml.ns import qn

# 1. 创建文档
doc = Document()

# 2. 添加标题
heading = doc.add_heading("大模型实战", level=0)   # 0-9 : 0表示标题， 1-9表示目录
heading.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
run = heading.runs[0]
run.font.name = '微软雅黑'  # 设置西文字体（表面显示）
run._element.rPr.rFonts.set(qn('w:eastAsia'), '微软雅黑')

doc.add_picture("pic.jpg", width=Cm(4))
doc.add_table(rows=3, cols=3, style="Table Grid")

# 3. 保存文档
doc.save("model.docx")

# %% [markdown]
# # 02_PPT

# %% [markdown]
# ## 1. 环境安装

# %%
# %pip install python-pptx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [python-pptx] [python-pptx]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. 编程模式

# %% [markdown]
# ```text
#     1. 创建PPTX文档（可以直接加载模版）
#     2. 获取文档的默认板式，选择板式
#         - 索引0: TitleSlide
#         - 索引1: Title and Content
#         - ...
#         - 索引9:
#     3. 创建Slide(幻灯片)
#     4. 访问并添加内容
#     5. 保存PPT
# ```

# %% [markdown]
# # 3 exlsx

# %% [markdown]
# ## 1. 环境安装

# %%
# %pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. 步骤

# %% [markdown]
# 1. 创建workbook
# 2. 创建worksheet/激活默认的worksheet
# 3. 列
# 4. 行
# 5. 保存workbook

# %%
from openpyxl import Workbook

# 1. 创建workbook
wb = Workbook()

# 2. 激活Worksheet
ws = wb.active

# 3. 修改worksheet的名字
ws.title = "大纲"

# 4. 添加列
ws["A1"] = "章"
ws["B1"] = "节"
ws["C1"] = "知识点"
ws["D1"] = "教学要求"

ws["A2"] = "神经网络"
ws["B2"] = "神经元"
ws["C2"] = "输入层"
ws["D2"] = "掌握....."

ws.append(["神经网络", "神经元", "隐藏层", "掌握....."])


wb.save("/Users/logicye/Code/ai_learning/notebooks/08_开发工具/02_wps三件套编程/model.xlsx")

# %%
# ================== 2. 读取已有的 Excel 文件 ==================
# 加载刚才创建的文件
wb = load_workbook("products.xlsx")

# 获取名为 "产品价格表" 的工作表
ws = wb["大纲"]

# 读取单个单元格的值
product_name = ws['A2'].value
price = ws['B2'].value
print(f"\n✓ 读取数据: {product_name} 的价格是 {price} 元")

# 遍历工作表中的所有数据
print("\n--- 遍历所有产品数据 ---")
for row in ws.iter_rows(values_only=True):
    # row 是一个元组，例如 ('产品名称', '价格 (元)')
    print(f"产品: {row[0]}, 价格: {row[1]}")

# ================== 3. 修改单元格内容及样式 ==================
# 继续使用上面加载的 wb 对象
ws = wb["产品价格表"]

# 修改数据：将鼠标的价格改为 59
ws['B2'] = 59

# 设置样式：让表头字体加粗、变大并居中
header_font = Font(bold=True, size=12)
center_alignment = Alignment(horizontal='center')

for cell in ws[1]:  # ws[1] 表示第一行的所有单元格
    cell.font = header_font
    cell.alignment = center_alignment

# 将修改后的文件另存为新文件，避免覆盖原文件
wb.save("products_updated.xlsx")
print("生成带有样式的文件：products_updated.xlsx")
